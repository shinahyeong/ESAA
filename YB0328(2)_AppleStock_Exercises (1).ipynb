# %% [markdown]
# # Apple Stock

# %% [markdown]
# ### Introduction:
#
# We are going to use Apple's stock price.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv)

# %%
data = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv',sep=',')

# %% [markdown]
# ### Step 3. Assign it to a variable apple

# %%
apple = data
apple.head()
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 4.  Check out the type of the columns

# %%
print(apple.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8465 non-null   object
#  1   Open       8465 non-null   float64
#  2   High       8465 non-null   float64
#  3   Low        8465 non-null   float64
#  4   Close      8465 non-null   float64
#  5   Volume     8465 non-null   int64
#  6   Adj Close  8465 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 463.1+ KB
# None

# %% [markdown]
# .dtype을 이용하면 데이터 타입만 확인할 수 있음 (더 간편한 방법)

# %% [markdown]
# ### Step 5. Transform the Date column as a datetime type

# %%
apple['Date'] = pd.to_datetime(apple['Date'])
print(apple.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8465 non-null   datetime64[ns]
#  1   Open       8465 non-null   float64
#  2   High       8465 non-null   float64
#  3   Low        8465 non-null   float64
#  4   Close      8465 non-null   float64
#  5   Volume     8465 non-null   int64
#  6   Adj Close  8465 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 463.1 KB
# None

# %% [markdown]
# ### Step 6.  Set the date as the index

# %%
apple= apple.set_index('Date')
apple.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Step 7.  Is there any duplicate dates?

# %%
apple.index.duplicated()
apple.index.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Step 8.  Ops...it seems the index is from the most recent date. Make the first entry the oldest date.

# %%
apple = apple.sort_index(ascending=True)
apple.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %% [markdown]
# ### Step 9. Get the last business day of each month

# %%
apple.resample('BM').last()
# Out:
# <ipython-input-9-58bcf74cdf47>:1: FutureWarning: 'BM' is deprecated and will be removed in a future version, please use 'BME' instead.
#   apple.resample('BM').last()
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 1980-12-31   34.25   34.25   34.13   34.13    8937600       0.53
# 1981-01-30   28.50   28.50   28.25   28.25   11547200       0.44
# 1981-02-27   26.50   26.75   26.50   26.50    3690400       0.41
# 1981-03-31   24.75   24.75   24.50   24.50    3998400       0.38
# 1981-04-30   28.38   28.62   28.38   28.38    3152800       0.44
# ...            ...     ...     ...     ...        ...        ...
# 2014-03-31  539.23  540.81  535.93  536.74   42167300      76.25
# 2014-04-30  592.64  599.43  589.80  590.09  114160200      83.83
# 2014-05-30  637.98  644.17  628.90  633.00  141005200      90.43
# 2014-06-30   92.10   93.73   92.09   92.93   49482300      92.93
# 2014-07-31   96.27   96.80   93.92   95.35   65130000      95.35
#
# ...

# %% [markdown]
# - 여기서 BM은 Business Month End의 약자로, '각 월의 마지막 영업일'을 의미함.
# - 즉, apple data를 BM을 기준으로 resample()함수를 이용하여 재배열 해줌
# - 이후 last()함수를 이용하여 영업일의 마지막 날만 출력함

# %% [markdown]
# ### Step 10.  What is the difference in days between the first day and the oldest

# %%
diff = apple.index.max() - apple.index.min()
print(diff)
# Out:
# 12261 days 00:00:00

# %% [markdown]
# ### Step 11.  How many months in the data we have?

# %%
apple.resample('ME').size().shape[0]
# Out:
# 404

# %% [markdown]
# - ME: Month End를 나타내며 각 월의 마지막 영업일에 대한 데이터를 선택해줌
# - 이후 .size()를 이용하여 리샘플된 그룹의 개수를 세줌
# - shape[0]: shape로 DataFrame의 차원을 반환하는데 이때 0은 행의 개수를 반환
#
#   -> 데이터에서 각 월의 마지막 영업일에 해당하는 데이터의 개수를 세고 그 개수만 반환함

# %% [markdown]
# ### Step 12. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(13.5,9))
plt.plot(apple.index, apple['Adj Close'])

plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.show()
